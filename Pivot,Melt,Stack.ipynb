# %%
import numpy as np,pandas as pd

# %%
users = pd.read_csv('D:/Manipal Pro learn/Term1/Python_programming/Dataset/users.csv')
users
# Out:
#    Unnamed: 0 weekday    city  visitors  signups
# 0           0     Sun  Austin       139        7
# 1           1     Sun  Dallas       237       12
# 2           2     Mon  Austin       326        3
# 3           3     Mon  Dallas       456        5

# %%
users.pivot(index='weekday',columns='city',values='visitors')
# Out:
# city     Austin  Dallas
# weekday
# Mon         326     456
# Sun         139     237

# %%
users.pivot(index='weekday',columns='city',values='signups')
# Out:
# city     Austin  Dallas
# weekday
# Mon           3       5
# Sun           7      12

# %%
users.pivot(index='weekday',columns='city',values=['visitors','signups'])
# Out:
#         visitors        signups
# city      Austin Dallas  Austin Dallas
# weekday
# Mon          326    456       3      5
# Sun          139    237       7     12

# %%
#For pivoting all columns 
users.pivot(index='weekday',columns='city')
# Out:
#         Unnamed: 0        visitors        signups
# city        Austin Dallas   Austin Dallas  Austin Dallas
# weekday
# Mon              2      3      326    456       3      5
# Sun              0      1      139    237       7     12

# %%
users = users.set_index(['city','weekday'])
users
# Out:
#                 Unnamed: 0  visitors  signups
# city   weekday
# Austin Sun               0       139        7
# Dallas Sun               1       237       12
# Austin Mon               2       326        3
# Dallas Mon               3       456        5

# %%
#Unstack is similar to pivot on index columns
users.unstack('weekday')
# Out:
#         Unnamed: 0     visitors      signups
# weekday        Mon Sun      Mon  Sun     Mon Sun
# city
# Austin           2   0      326  139       3   7
# Dallas           3   1      456  237       5  12

# %%
#stack is similar to melt on index columns
users.unstack('city').stack('city')
# Out:
#                 Unnamed: 0  visitors  signups
# weekday city
# Mon     Austin           2       326        3
#         Dallas           3       456        5
# Sun     Austin           0       139        7
#         Dallas           1       237       12

# %%
bycity = users.unstack('city')
bycity
# Out:
#         Unnamed: 0        visitors        signups
# city        Austin Dallas   Austin Dallas  Austin Dallas
# weekday
# Mon              2      3      326    456       3      5
# Sun              0      1      139    237       7     12

# %%
bycity1 = bycity.stack('city')
bycity1
# Out:
#                 Unnamed: 0  visitors  signups
# weekday city
# Mon     Austin           2       326        3
#         Dallas           3       456        5
# Sun     Austin           0       139        7
#         Dallas           1       237       12

# %%
newusers = bycity.stack('city')
newusers
# Out:
#                 Unnamed: 0  visitors  signups
# weekday city
# Mon     Austin           2       326        3
#         Dallas           3       456        5
# Sun     Austin           0       139        7
#         Dallas           1       237       12

# %%
newusers = bycity1.swaplevel(0,1)
newusers
# Out:
#                 Unnamed: 0  visitors  signups
# city   weekday
# Austin Mon               2       326        3
# Dallas Mon               3       456        5
# Austin Sun               0       139        7
# Dallas Sun               1       237       12

# %%
newusers.sort_index()
# Out:
#                 Unnamed: 0  visitors  signups
# city   weekday
# Austin Mon               2       326        3
#        Sun               0       139        7
# Dallas Mon               3       456        5
#        Sun               1       237       12

# %%
users
# Out:
#                 Unnamed: 0  visitors  signups
# city   weekday
# Austin Sun               0       139        7
# Dallas Sun               1       237       12
# Austin Mon               2       326        3
# Dallas Mon               3       456        5

# %%
users = pd.read_csv('D:/Manipal Pro learn/Term1/Python_programming/Dataset/users.csv')

visitors_by_city_weekday = users.pivot('weekday','city','visitors')
visitors_by_city_weekday
# Out:
# city     Austin  Dallas
# weekday
# Mon         326     456
# Sun         139     237

# %%
visitors_by_city_weekday = visitors_by_city_weekday.reset_index()
visitors_by_city_weekday
# Out:
# city weekday  Austin  Dallas
# 0        Mon     326     456
# 1        Sun     139     237

# %%
visitors_by_city_weekday.melt(id_vars='weekday',var_name='city',value_name='visitors')
# Out:
#   weekday    city  visitors
# 0     Mon  Austin       326
# 1     Sun  Austin       139
# 2     Mon  Dallas       456
# 3     Sun  Dallas       237

# %%
users = users[1:]
users

# %%
users
# Out:
#    Unnamed: 0 weekday    city  visitors  signups
# 1           1     Sun  Dallas       237       12
# 2           2     Mon  Austin       326        3
# 3           3     Mon  Dallas       456        5

# %%
users.melt(id_vars=['weekday','city'],var_name='visit and signups',value_name='user')
# Out:
#    weekday    city visit and signups  user
# 0      Sun  Austin        Unnamed: 0     0
# 1      Sun  Dallas        Unnamed: 0     1
# 2      Mon  Austin        Unnamed: 0     2
# 3      Mon  Dallas        Unnamed: 0     3
# 4      Sun  Austin          visitors   139
# 5      Sun  Dallas          visitors   237
# 6      Mon  Austin          visitors   326
# 7      Mon  Dallas          visitors   456
# 8      Sun  Austin           signups     7
# 9      Sun  Dallas           signups    12
# 10     Mon  Austin           signups     3
# 11     Mon  Dallas           signups     5

# %%
user1 = users.set_index(['weekday','city'])
user1
# Out:
#                 Unnamed: 0  visitors  signups
# weekday city
# Sun     Austin           0       139        7
#         Dallas           1       237       12
# Mon     Austin           2       326        3
#         Dallas           3       456        5

# %%
user1= user1[['visitors','signups']]
user1
# Out:
#                 visitors  signups
# weekday city
# Sun     Austin       139        7
#         Dallas       237       12
# Mon     Austin       326        3
#         Dallas       456        5

# %%
user1.melt(col_level=0)
# Out:
#    variable  value
# 0  visitors    139
# 1  visitors    237
# 2  visitors    326
# 3  visitors    456
# 4   signups      7
# 5   signups     12
# 6   signups      3
# 7   signups      5

# %%
users = users.iloc[:,1:]
users
# Out:
#   weekday    city  visitors  signups
# 0     Sun  Austin       139        7
# 1     Sun  Dallas       237       12
# 2     Mon  Austin       326        3
# 3     Mon  Dallas       456        5

# %%
userpivot = users.pivot(index='weekday',columns='city')
userpivot
# Out:
#         visitors        signups
# city      Austin Dallas  Austin Dallas
# weekday
# Mon          326    456       3      5
# Sun          139    237       7     12

# %%
userpivot1 = users.pivot_table(index='weekday',columns='city',aggfunc='count')
userpivot1
# Out:
#         signups        visitors
# city     Austin Dallas   Austin Dallas
# weekday
# Mon           1      1        1      1
# Sun           1      1        1      1

# %%
users.pivot_table(index='weekday',columns='city',aggfunc=len)
# Out:
#         signups        visitors
# city     Austin Dallas   Austin Dallas
# weekday
# Mon           1      1        1      1
# Sun           1      1        1      1

# %%
users.pivot_table(index='weekday',columns='city',aggfunc=sum,margins=True)
# Out:
#         signups            visitors
# city     Austin Dallas All   Austin Dallas   All
# weekday
# Mon           3      5   8      326    456   782
# Sun           7     12  19      139    237   376
# All          10     17  27      465    693  1158
